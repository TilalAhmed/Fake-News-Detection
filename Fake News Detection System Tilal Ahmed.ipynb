# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
data_fake = pd.read_csv('D:\\jn\\Fake.csv')
data_true = pd.read_csv('D:\\jn\\True.csv')

# %%
# To see top 5 rows of the data set 'fake'
data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
# To see bottom 5 rows of the data set 'fake'
data_fake.tail()
# Out:
#                                                    title  \
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date
# 23476  January 16, 2016
# 23477  January 16, 2016
# 23478  January 15, 2016
# 23479  January 14, 2016
# 23480  January 12, 2016

# %%
# To see top 5 rows of the data set 'true'
data_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
# To see bottom 5 rows of the data set 'true'
data_true.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
#inserting column class as target feature
data_fake["class"]= 0
data_true['class']= 1

# %%
data_fake.shape, data_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
#removing bottom 10 rows of the manual testing
data_fake_manual_testing = data_fake.tail(10)
for i in range(23480,23470,-1):
    data_fake.drop([i],axis=0,inplace=True)

data_true_manual_testing = data_true.tail(10)
for i in range(21416,21406,-1):
    data_true.drop([i],axis=0,inplace=True)

# %% [markdown]
# # 10 Rows have been deleted from each data set

# %%
data_fake.shape, data_true.shape
# Out:
# ((23471, 5), (21407, 5))

# %%
#data_fake_manual_testing['class'] = 0
#data_true_manual_testing['class'] = 1
data_fake_manual_testing = data_fake.tail(10).copy()
data_fake_manual_testing['class'] = 0

data_true_manual_testing = data_true.tail(10).copy()
data_true_manual_testing['class'] = 1

# %%
data_fake_manual_testing.head()
# Out:
#                                                    title  \
# 23461  REPORT: ‘Federal Government Escalated the Viol...
# 23462  BOILER ROOM – Oregon Standoff, Cuddle Parties,...
# 23463  Eyewitness Says Feds Ambushed Bundys, 100 Shot...
# 23464  Episode #119 – SUNDAY WIRE: ‘You Know the Dril...
# 23465  ‘There’ll be boots on the ground’: US making n...
#
#                                                     text      subject  \
# 23461   KILLED: Rancher and protest spokesman Robert ...  Middle-east
# 23462  Tune in to the Alternate Current Radio Network...  Middle-east
# 23463  Patrick Henningsen 21st Century Wire UPDATE: 1...  Middle-east
# 23464  Episode #119 of SUNDAY WIRE SHOW finally resum...  Middle-east
# 23465  21st Century Wire says Various parties in Wash...  Middle-east
#
#                    date  class
# 23461  January 28, 2016      0
# 23462  January 28, 2016      0
# 23463  January 27, 2016      0
# 23464  January 24, 2016      0
# 23465  January 23, 2016      0

# %%
data_true_manual_testing.head(10)
# Out:
#                                                    title  \
# 21397  Germany's Schulz says he would demand U.S. wit...
# 21398  Blunt instrument? What a list of banned articl...
# 21399  Saudi police release teenager detained for dan...
# 21400  The People's Princess, Britons work to keep me...
# 21401  Argentina labor unions protest job losses, Mac...
# 21402  Exclusive: Trump's Afghan decision may increas...
# 21403  U.S. puts more pressure on Pakistan to help wi...
# 21404  Exclusive: U.S. to withhold up to $290 million...
# 21405  Trump talks tough on Pakistan's 'terrorist' ha...
# 21406  U.S., North Korea clash at U.N. forum over nuc...
#
#                                                     text    subject  \
# 21397  BERLIN (Reuters) - The leader of Germany s Soc...  worldnews
# 21398  SHANGHAI (Reuters) - An old review of an acade...  worldnews
# 21399  DUBAI (Reuters) - A 14-year-old boy who was de...  worldnews
# ...

# %% [markdown]
# # Merging top 10 rows of both data set

# %%
data_merge = pd.concat([data_fake, data_true], axis = 0)
data_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
#Removing those columns which are not required
data =data_merge.drop(['title','subject','date'], axis = 1)

# %%
#To check if there are any null values
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %% [markdown]
# # So there are no null values as you can see above

# %%
#Random shuffling of the data frames
data = data.sample(frac=1)

# %%
data.head()
# Out:
#                                                     text  class
# 3425   WASHINGTON (Reuters) - President Donald Trump ...      1
# 20677  WASHINGTON/BEIJING (Reuters) - U.S. President ...      1
# 19058  NEW YORK (Reuters) - The Supreme Court signale...      1
# 8323   When comedian Alison Leiby tweeted a pretty cu...      0
# 19667  The only way Hillary and Tim Kaine can win thi...      0

# %% [markdown]
# # Random shuffeling is done class 1 is for true and 0 is for false data set

# %%
data.reset_index(inplace=True)
data.drop(['index'],axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.head()
# Out:
#                                                 text  class
# 0  WASHINGTON (Reuters) - President Donald Trump ...      1
# 1  WASHINGTON/BEIJING (Reuters) - U.S. President ...      1
# 2  NEW YORK (Reuters) - The Supreme Court signale...      1
# 3  When comedian Alison Leiby tweeted a pretty cu...      0
# 4  The only way Hillary and Tim Kaine can win thi...      0

# %% [markdown]
# # So we have two columns left three columns have been deleted

# %%
#creating a function to process the text
def tilal(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text) 
    text = re.sub(r"\\W", " ", text)     
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    return text

# %%
data['text']=data['text'].apply(tilal)

# %%
#finding dependent and independent variables
x = data['text']
y = data['class']

# %%
#splitting training and testing data
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.25)

# %%
#converting text to vectors
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9855614973262032

# %% [markdown]
# # Here we got the accuracy score

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5857
#            1       0.98      0.99      0.98      5363
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# # DecisionTreeClassification

# %%
from sklearn.tree import  DecisionTreeClassifier

DT =DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
#for accuracy
DT.score(xv_test, y_test)
# Out:
# 0.9967023172905526

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5857
#            1       1.00      1.00      1.00      5363
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

GB = GradientBoostingClassifier(random_state =0)
GB.fit(xv_train, y_train)

# %%
pred_gb = GB.predict(xv_test)

# %%
#for accuracy
GB.score(xv_test, y_test)

# %%
print(classification_report(y_test, pred_gb))

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(random_state =0)
RF.fit(xv_train, y_train)

# %%
pred_rf = RF.predict(xv_test)

# %%
#for accuracy
RF.score(xv_test, y_test)

# %%
print(classification_report(y_test, pred_rf))

# %% [markdown]
# # SupportVectorMachine

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

SVC = LinearSVC(random_state=0)
SVC.fit(xv_train, y_train)

# %%
pred_svc = SVC.predict(xv_test)

# %%
#for accuracy
SVC.score(xv_test, y_test)

# %%
print(classification_report(y_test, pred_svc))

# %% [markdown]
# # NaiveBayes

# %%
from sklearn.naive_bayes import MultinomialNB

NB = MultinomialNB()
NB.fit(xv_train, y_train)

# %%
pred_nb = NB.predict(xv_test)

# %%
#for accuracy
NB.score(xv_test, y_test)

# %%
print(classification_report(y_test, pred_nb))

# %%
def output_label(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "True News"

def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(tilal)  
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GB = GB.predict(new_xv_test)
    pred_RF = RF.predict(new_xv_test)
    pred_SVC = SVC.predict(new_xv_test)
    pred_NB = NB.predict(new_xv_test)

    print("\n\nLR Prediction: {} \nDT Prediction: {} \nGB Prediction: {} \nRF Prediction: {} \nSVC Prediction: {} \nNB Prediction: {}".format(
        output_label(pred_LR[0]),
        output_label(pred_DT[0]),
        output_label(pred_GB[0]),
        output_label(pred_RF[0]),
        output_label(pred_SVC[0]),
        output_label(pred_NB[0])
    ))

# %%
#checking wether the news is fake or true by putting a true news
news = str(input())
manual_testing(news)

# %%
#checking wether the news is fake or true by putting a fake news
news = str(input())
manual_testing(news)

# %%
import pickle

pickle.dump(LR, open("model.pkl", "wb"))
pickle.dump(vectorization, open("vectorizer.pkl", "wb"))
